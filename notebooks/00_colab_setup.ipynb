# %% [markdown]
# # Colab setup\n\nUse this notebook to mount Drive, install dependencies, and point the scripts at the shared repo and dataset.

# %%
from google.colab import drive\ndrive.mount('/content/drive')

# %%
from pathlib import Path\n\nrepo_root = Path('/content/drive/MyDrive/lpsrocr')\ndataset_root = repo_root / 'train'\nmanifests_root = repo_root / 'manifests'\noutputs_root = repo_root / 'outputs'\nrepo_root, dataset_root, manifests_root, outputs_root

# %%
# Install local requirements when the repo is available in Drive.\n# !cd /content/drive/MyDrive/lpsrocr && pip install -r requirements.txt
